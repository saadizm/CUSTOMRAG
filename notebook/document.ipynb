# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content. I am using to create RAG",
    metadata = {
        "source":"Example.txt",
        "pages":1,
        "author":"Saad Ahmed",
        "date_created": "2026-05-11"
    }
)
doc
# Out:
# Document(metadata={'source': 'Example.txt', 'pages': 1, 'author': 'Saad Ahmed', 'date_created': '2026-05-11'}, page_content='This is the main text content. I am using to create RAG')

# %%
import os
os.makedirs('../data/text_files',exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt":"""
        Python is a high-level, general-purpose programming language known for its simple, readable syntax and beginner-friendly design. It was created to make programming easier to understand while still being powerful enough for professional software development. Because Python code often looks close to plain English, it is widely used by students, developers, researchers, and companies for learning programming, building applications, automating tasks, and solving real-world problems.
        Python has a lot to offer across many fields. It is commonly used in web development, data science, artificial intelligence, machine learning, automation, scripting, cybersecurity, game development, and scientific computing. Python also has a huge ecosystem of libraries and frameworks, such as Django, Flask, NumPy, Pandas, TensorFlow, and PyTorch, which help developers build projects faster. Its strong community support, cross-platform compatibility, and large number of learning resources make it one of the most popular and versatile programming languages today.
    """
}

for filepath, content in sample_text.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)

print("Sample text files created..")
# Out:
# Sample text files created..

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, general-purpose programming language known for its simple, readable syntax and beginner-friendly design. It was created to make programming easier to understand while still being powerful enough for professional software development. Because Python code often looks close to plain English, it is widely used by students, developers, researchers, and companies for learning programming, building applications, automating tasks, and solving real-world problems.\nPython has a lot to offer across many fields. It is commonly used in web development, data science, artificial intelligence, machine learning, automation, scripting, cybersecurity, game development, and scientific computing. Python also has a huge ecosystem of libraries and frameworks, such as Django, Flask, NumPy, Pandas, TensorFlow, and PyTorch, which help developers build projects faster. Its strong community support, cros
# ...

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

documents = dir_loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, general-purpose programming language known for its simple, readable syntax and beginner-friendly design. It was created to make programming easier to understand while still being powerful enough for professional software development. Because Python code often looks close to plain English, it is widely used by students, developers, researchers, and companies for learning programming, building applications, automating tasks, and solving real-world problems.\nPython has a lot to offer across many fields. It is commonly used in web development, data science, artificial intelligence, machine learning, automation, scripting, cybersecurity, game development, and scientific computing. Python also has a huge ecosystem of libraries and frameworks, such as Django, Flask, NumPy, Pandas, TensorFlow, and PyTorch, which help developers build projects faster. Its strong community support, cros
# ...

# %%
### Pdf loader
from langchain_community.document_loaders import PyMuPDFLoader

pdf_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

documents = pdf_loader.load()
documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T07:13:12+00:00', 'source': '../data/pdf_files/attention_mechanisms_basic_information.pdf', 'file_path': '../data/pdf_files/attention_mechanisms_basic_information.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T07:13:12+00:00', 'trapped': '', 'modDate': "D:20260511071312+00'00'", 'creationDate': "D:20260511071312+00'00'", 'page': 0}, page_content='Basic Information About Attention Mechanisms\nAttention mechanisms are techniques used in machine learning models to decide which parts\nof the input are most important for a given task. Instead of treating every word or token\nequally, attention allows the model to focus more strongly on relevant information.\nIn language models, attention helps connect words across a sentence or document. For\nexample, 
# ...
